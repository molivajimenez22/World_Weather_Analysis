# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
import time

# Import the time library and the datetime module from the datetime library 
from datetime import datetime

# Import linregress
from scipy.stats import linregress

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the names of cities.
cities = list()

#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    cities_name = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if cities_name not in cities:
        cities.append(cities_name)

len(cities)
# Out:
# 772

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=037ef36f8a4a535cc44a92c6eddc596e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dunedin
# Processing Record 2 of Set 1 | oistins
# Processing Record 3 of Set 1 | acarau
# Processing Record 4 of Set 1 | rognan
# Processing Record 5 of Set 1 | iquitos
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | dingle
# Processing Record 8 of Set 1 | haines junction
# Processing Record 9 of Set 1 | eslamshahr
# Processing Record 10 of Set 1 | awjilah
# Processing Record 11 of Set 1 | aracati
# Processing Record 12 of Set 1 | corowa
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | mackay
# Processing Record 15 of Set 1 | sibolga
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | lypova dolyna
# Processing Record 18 of Set 1 | bajo baudo
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | guerrero negro
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | yabelo
# Processing Record 23 of Set 1 | ayan
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | kawalu
# Processing Record 30 of Set 1 | banda aceh
# Processing Record 31 of Set 1 | sampang
# Processing Record 32 of Set 1 | iquique
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | ormara
# Processing Record 35 of Set 1 | georgiyevka
# Processing Record 36 of Set 1 | klaksvik
# Processing Record 37 of Set 1 | yanam
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | grand gaube
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | hofn
# Processing Record 44 of Set 1 | kyzyl
# Processing Record 45 of Set 1 | ornskoldsvik
# Processing Record 46 of Set 1 | pacific grove
# Processing Record 47 of Set 1 | ocos
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | richards bay
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | mago
# Processing Record 2 of Set 2 | narsaq
# Processing Record 3 of Set 2 | harper
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | cabo san lucas
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | alta floresta
# Processing Record 9 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 2 | gorontalo
# Processing Record 11 of Set 2 | karpathos
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | khor
# Processing Record 15 of Set 2 | itoman
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | pangkalanbuun
# Processing Record 19 of Set 2 | port moresby
# Processing Record 20 of Set 2 | te anau
# Processing Record 21 of Set 2 | alappuzha
# Processing Record 22 of Set 2 | margate
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | insar
# Processing Record 28 of Set 2 | ondjiva
# Processing Record 29 of Set 2 | sitka
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | codrington
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | san patricio
# Processing Record 36 of Set 2 | zaraza
# Processing Record 37 of Set 2 | lagdo
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | waihi beach
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | san pedro
# Processing Record 42 of Set 2 | rawson
# Processing Record 43 of Set 2 | leningradskiy
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | shimoda
# Processing Record 47 of Set 2 | bure
# Processing Record 48 of Set 2 | nikolskoye
# Processing Record 49 of Set 2 | leh
# Processing Record 50 of Set 2 | san vicente
# Processing Record 1 of Set 3 | fortuna
# Processing Record 2 of Set 3 | la esperanza
# Processing Record 3 of Set 3 | verkhnyaya inta
# Processing Record 4 of Set 3 | versalles
# Processing Record 5 of Set 3 | morondava
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | qandala
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | kruisfontein
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | mount isa
# Processing Record 14 of Set 3 | bagdarin
# Processing Record 15 of Set 3 | nkowakowa
# Processing Record 16 of Set 3 | nemuro
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | sao joao da barra
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | elko
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | heihe
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | phibun mangsahan
# Processing Record 27 of Set 3 | jiangkou
# Processing Record 28 of Set 3 | oranjemund
# Processing Record 29 of Set 3 | alassio
# Processing Record 30 of Set 3 | jamestown
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | aklavik
# Processing Record 34 of Set 3 | rio grande
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | luderitz
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 39 of Set 3 | anloga
# Processing Record 40 of Set 3 | kariba
# Processing Record 41 of Set 3 | sinnamary
# Processing Record 42 of Set 3 | bapatla
# Processing Record 43 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | cape town
# Processing Record 46 of Set 3 | lithakia
# Processing Record 47 of Set 3 | tiksi
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | jumla
# Processing Record 50 of Set 3 | bestobe
# Processing Record 1 of Set 4 | florida
# Processing Record 2 of Set 4 | laguna
# Processing Record 3 of Set 4 | barbastro
# Processing Record 4 of Set 4 | severo-kurilsk
# Processing Record 5 of Set 4 | sosnovo-ozerskoye
# Processing Record 6 of Set 4 | sao filipe
# Processing Record 7 of Set 4 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | kharp
# Processing Record 10 of Set 4 | nome
# Processing Record 11 of Set 4 | atar
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | los llanos de aridane
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | barrow
# Processing Record 16 of Set 4 | araouane
# Processing Record 17 of Set 4 | camacha
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | frederico westphalen
# Processing Record 20 of Set 4 | nehe
# Processing Record 21 of Set 4 | prisacani
# Processing Record 22 of Set 4 | paita
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | saldanha
# Processing Record 25 of Set 4 | saint-augustin
# Processing Record 26 of Set 4 | sungairaya
# Processing Record 27 of Set 4 | sarab
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | sheridan
# Processing Record 32 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 4 | husavik
# Processing Record 34 of Set 4 | skorodnoye
# Processing Record 35 of Set 4 | anito
# Processing Record 36 of Set 4 | praya
# Processing Record 37 of Set 4 | alcaniz
# Processing Record 38 of Set 4 | touros
# Processing Record 39 of Set 4 | fartura
# Processing Record 40 of Set 4 | asau
# Processing Record 41 of Set 4 | chicama
# Processing Record 42 of Set 4 | tucumcari
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | ixtapa
# Processing Record 45 of Set 4 | beringovskiy
# Processing Record 46 of Set 4 | los alamos
# Processing Record 47 of Set 4 | hithadhoo
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | blagodatnoye
# Processing Record 50 of Set 4 | menongue
# Processing Record 1 of Set 5 | butaritari
# Processing Record 2 of Set 5 | prince george
# Processing Record 3 of Set 5 | lake charles
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | bogorodskoye
# Processing Record 6 of Set 5 | chokurdakh
# Processing Record 7 of Set 5 | stornoway
# Processing Record 8 of Set 5 | cap-aux-meules
# Processing Record 9 of Set 5 | najran
# Processing Record 10 of Set 5 | alyangula
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | taoudenni
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | pevek
# Processing Record 15 of Set 5 | lima
# Processing Record 16 of Set 5 | port barton
# Processing Record 17 of Set 5 | saravan
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | lewistown
# Processing Record 20 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 21 of Set 5 | dandong
# Processing Record 22 of Set 5 | vestmannaeyjar
# Processing Record 23 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 5 | abong mbang
# Processing Record 25 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 5 | dulce grande
# Processing Record 27 of Set 5 | lafia
# Processing Record 28 of Set 5 | mahibadhoo
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 5 | brae
# Processing Record 32 of Set 5 | golden
# Processing Record 33 of Set 5 | alice springs
# Processing Record 34 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 5 | coihaique
# Processing Record 36 of Set 5 | saint-pierre
# Processing Record 37 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 5 | roald
# Processing Record 39 of Set 5 | la rioja
# Processing Record 40 of Set 5 | pio ix
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | portland
# Processing Record 43 of Set 5 | katobu
# Processing Record 44 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 5 | algiers
# Processing Record 47 of Set 5 | puerto madero
# Processing Record 48 of Set 5 | zhangjiakou
# Processing Record 49 of Set 5 | hami
# Processing Record 50 of Set 5 | chumikan
# Processing Record 1 of Set 6 | flinders
# Processing Record 2 of Set 6 | mount gambier
# Processing Record 3 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 4 of Set 6 | cabedelo
# Processing Record 5 of Set 6 | north platte
# Processing Record 6 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 7 of Set 6 | comodoro rivadavia
# Processing Record 8 of Set 6 | surenavan
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | mombetsu
# Processing Record 11 of Set 6 | kalabo
# Processing Record 12 of Set 6 | hokitika
# Processing Record 13 of Set 6 | airai
# Processing Record 14 of Set 6 | nalut
# Processing Record 15 of Set 6 | chipinge
# Processing Record 16 of Set 6 | naryan-mar
# Processing Record 17 of Set 6 | sembakung
# Processing Record 18 of Set 6 | okhotsk
# Processing Record 19 of Set 6 | saskylakh
# Processing Record 20 of Set 6 | kuytun
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 6 | port-gentil
# Processing Record 24 of Set 6 | casablanca
# Processing Record 25 of Set 6 | diamantino
# Processing Record 26 of Set 6 | ossora
# Processing Record 27 of Set 6 | portobelo
# Processing Record 28 of Set 6 | tessalit
# Processing Record 29 of Set 6 | fort nelson
# Processing Record 30 of Set 6 | tambura
# Processing Record 31 of Set 6 | moerai
# Processing Record 32 of Set 6 | bobrovytsya
# Processing Record 33 of Set 6 | deputatskiy
# Processing Record 34 of Set 6 | kemijarvi
# Processing Record 35 of Set 6 | aurillac
# Processing Record 36 of Set 6 | churapcha
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | constitucion
# Processing Record 39 of Set 6 | america dourada
# Processing Record 40 of Set 6 | torbay
# Processing Record 41 of Set 6 | islamkot
# Processing Record 42 of Set 6 | pindiga
# Processing Record 43 of Set 6 | naze
# Processing Record 44 of Set 6 | tulsipur
# Processing Record 45 of Set 6 | zhigansk
# Processing Record 46 of Set 6 | mitsamiouli
# Processing Record 47 of Set 6 | madang
# Processing Record 48 of Set 6 | burns lake
# Processing Record 49 of Set 6 | poum
# Processing Record 50 of Set 6 | lexington
# Processing Record 1 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 7 | murray bridge
# Processing Record 3 of Set 7 | babag
# Processing Record 4 of Set 7 | barkot
# Processing Record 5 of Set 7 | labuhan
# Processing Record 6 of Set 7 | port keats
# Processing Record 7 of Set 7 | ko samui
# Processing Record 8 of Set 7 | srivardhan
# Processing Record 9 of Set 7 | gouyave
# Processing Record 10 of Set 7 | kieta
# Processing Record 11 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 7 | bethel
# Processing Record 13 of Set 7 | charlestown
# Processing Record 14 of Set 7 | cotonou
# Processing Record 15 of Set 7 | yumen
# Processing Record 16 of Set 7 | grindavik
# Processing Record 17 of Set 7 | grand-santi
# Processing Record 18 of Set 7 | katsuura
# Processing Record 19 of Set 7 | boa vista
# Processing Record 20 of Set 7 | ebano
# City not found. Skipping...
# Processing Record 21 of Set 7 | westport
# Processing Record 22 of Set 7 | byron bay
# Processing Record 23 of Set 7 | ust-nera
# Processing Record 24 of Set 7 | ulety
# Processing Record 25 of Set 7 | flin flon
# Processing Record 26 of Set 7 | thunder bay
# Processing Record 27 of Set 7 | kaeo
# Processing Record 28 of Set 7 | hobyo
# Processing Record 29 of Set 7 | boddam
# Processing Record 30 of Set 7 | petrolina
# Processing Record 31 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 7 | kaitangata
# Processing Record 33 of Set 7 | bengkulu
# Processing Record 34 of Set 7 | talnakh
# Processing Record 35 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | clyde river
# Processing Record 37 of Set 7 | port lincoln
# Processing Record 38 of Set 7 | suntar
# Processing Record 39 of Set 7 | faanui
# Processing Record 40 of Set 7 | lardos
# Processing Record 41 of Set 7 | rafai
# Processing Record 42 of Set 7 | cocachacra
# Processing Record 43 of Set 7 | saurimo
# Processing Record 44 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 7 | evanston
# Processing Record 46 of Set 7 | joensuu
# Processing Record 47 of Set 7 | fairbanks
# Processing Record 48 of Set 7 | saundatti yellamma
# City not found. Skipping...
# Processing Record 49 of Set 7 | hearst
# Processing Record 50 of Set 7 | mogadishu
# Processing Record 1 of Set 8 | ostrovnoy
# Processing Record 2 of Set 8 | loreto
# Processing Record 3 of Set 8 | erpeli
# Processing Record 4 of Set 8 | linares
# Processing Record 5 of Set 8 | umirim
# Processing Record 6 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 8 | salcininkai
# Processing Record 8 of Set 8 | mikhaylovka
# Processing Record 9 of Set 8 | daitari
# Processing Record 10 of Set 8 | kushiro
# Processing Record 11 of Set 8 | roma
# Processing Record 12 of Set 8 | lasa
# Processing Record 13 of Set 8 | namatanai
# Processing Record 14 of Set 8 | myanaung
# Processing Record 15 of Set 8 | yelovo
# Processing Record 16 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | carutapera
# Processing Record 18 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 8 | srednekolymsk
# Processing Record 20 of Set 8 | kavieng
# Processing Record 21 of Set 8 | gunjur
# Processing Record 22 of Set 8 | nyahururu
# Processing Record 23 of Set 8 | chapais
# Processing Record 24 of Set 8 | lisakovsk
# Processing Record 25 of Set 8 | colares
# Processing Record 26 of Set 8 | winslow
# Processing Record 27 of Set 8 | nuuk
# Processing Record 28 of Set 8 | kuching
# Processing Record 29 of Set 8 | gigmoto
# Processing Record 30 of Set 8 | valparaiso
# Processing Record 31 of Set 8 | nazret
# Processing Record 32 of Set 8 | martapura
# Processing Record 33 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 8 | lamar
# Processing Record 35 of Set 8 | hovd
# Processing Record 36 of Set 8 | isangel
# Processing Record 37 of Set 8 | tazovskiy
# Processing Record 38 of Set 8 | outram
# Processing Record 39 of Set 8 | hamilton
# Processing Record 40 of Set 8 | abha
# Processing Record 41 of Set 8 | north bend
# Processing Record 42 of Set 8 | gayny
# Processing Record 43 of Set 8 | yaan
# Processing Record 44 of Set 8 | atkinson
# Processing Record 45 of Set 8 | zambezi
# Processing Record 46 of Set 8 | muncar
# Processing Record 47 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 8 | kisangani
# Processing Record 49 of Set 8 | jieshi
# Processing Record 50 of Set 8 | malanje
# Processing Record 1 of Set 9 | emba
# Processing Record 2 of Set 9 | boende
# Processing Record 3 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 9 | fare
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | morant bay
# Processing Record 7 of Set 9 | nancha
# Processing Record 8 of Set 9 | kilindoni
# Processing Record 9 of Set 9 | wajima
# Processing Record 10 of Set 9 | castro
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | hukuntsi
# Processing Record 13 of Set 9 | inhambane
# Processing Record 14 of Set 9 | vostok
# Processing Record 15 of Set 9 | beloha
# Processing Record 16 of Set 9 | eunice
# Processing Record 17 of Set 9 | madridejos
# Processing Record 18 of Set 9 | bowen
# Processing Record 19 of Set 9 | uitenhage
# Processing Record 20 of Set 9 | namtsy
# Processing Record 21 of Set 9 | maragogi
# Processing Record 22 of Set 9 | upington
# Processing Record 23 of Set 9 | gwadar
# Processing Record 24 of Set 9 | shieli
# Processing Record 25 of Set 9 | abu kamal
# Processing Record 26 of Set 9 | saint-francois
# Processing Record 27 of Set 9 | yanacancha
# Processing Record 28 of Set 9 | tuatapere
# Processing Record 29 of Set 9 | eyemouth
# Processing Record 30 of Set 9 | bell ville
# Processing Record 31 of Set 9 | vestmanna
# Processing Record 32 of Set 9 | francisco beltrao
# Processing Record 33 of Set 9 | gazli
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | caravelas
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | marsh harbour
# Processing Record 38 of Set 9 | shingu
# Processing Record 39 of Set 9 | erenhot
# Processing Record 40 of Set 9 | bandarbeyla
# Processing Record 41 of Set 9 | weligama
# Processing Record 42 of Set 9 | sao jose da coroa grande
# Processing Record 43 of Set 9 | buraydah
# Processing Record 44 of Set 9 | allapalli
# Processing Record 45 of Set 9 | kuusamo
# Processing Record 46 of Set 9 | taltal
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | ulaanbaatar
# Processing Record 49 of Set 9 | araxa
# Processing Record 50 of Set 9 | yunyang
# Processing Record 1 of Set 10 | waitati
# Processing Record 2 of Set 10 | mantua
# Processing Record 3 of Set 10 | ariquemes
# Processing Record 4 of Set 10 | corpus christi
# Processing Record 5 of Set 10 | yulara
# Processing Record 6 of Set 10 | miraflores
# Processing Record 7 of Set 10 | bolobo
# Processing Record 8 of Set 10 | gangapur
# Processing Record 9 of Set 10 | amapa
# Processing Record 10 of Set 10 | sarahan
# Processing Record 11 of Set 10 | yenagoa
# Processing Record 12 of Set 10 | saint anthony
# Processing Record 13 of Set 10 | azle
# Processing Record 14 of Set 10 | praia
# Processing Record 15 of Set 10 | dongsheng
# Processing Record 16 of Set 10 | muros
# Processing Record 17 of Set 10 | karratha
# Processing Record 18 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 19 of Set 10 | humenne
# Processing Record 20 of Set 10 | guaratinga
# Processing Record 21 of Set 10 | bayangol
# Processing Record 22 of Set 10 | watsa
# Processing Record 23 of Set 10 | yerbogachen
# Processing Record 24 of Set 10 | banikoara
# Processing Record 25 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 10 | college
# Processing Record 27 of Set 10 | cayenne
# Processing Record 28 of Set 10 | sacele
# Processing Record 29 of Set 10 | geraldton
# Processing Record 30 of Set 10 | marianske lazne
# Processing Record 31 of Set 10 | trinidad
# Processing Record 32 of Set 10 | ampanihy
# Processing Record 33 of Set 10 | cuamba
# Processing Record 34 of Set 10 | niefern-oschelbronn
# Processing Record 35 of Set 10 | baykalsk
# Processing Record 36 of Set 10 | namalenga
# Processing Record 37 of Set 10 | yar-sale
# Processing Record 38 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | pak phanang
# Processing Record 40 of Set 10 | anadyr
# Processing Record 41 of Set 10 | mayor pablo lagerenza
# Processing Record 42 of Set 10 | yingcheng
# Processing Record 43 of Set 10 | gilgit
# Processing Record 44 of Set 10 | kloulklubed
# Processing Record 45 of Set 10 | sao domingos
# Processing Record 46 of Set 10 | kapuskasing
# Processing Record 47 of Set 10 | peniche
# Processing Record 48 of Set 10 | evensk
# Processing Record 49 of Set 10 | dunmore east
# Processing Record 50 of Set 10 | pierre
# Processing Record 1 of Set 11 | kenitra
# Processing Record 2 of Set 11 | kyabe
# Processing Record 3 of Set 11 | caconda
# Processing Record 4 of Set 11 | lavrentiya
# Processing Record 5 of Set 11 | batesville
# Processing Record 6 of Set 11 | komsomolskiy
# Processing Record 7 of Set 11 | coari
# Processing Record 8 of Set 11 | lompoc
# Processing Record 9 of Set 11 | berestechko
# Processing Record 10 of Set 11 | nogales
# Processing Record 11 of Set 11 | cuenca
# Processing Record 12 of Set 11 | lakes entrance
# Processing Record 13 of Set 11 | bakchar
# Processing Record 14 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 11 | bulawayo
# Processing Record 16 of Set 11 | diffa
# Processing Record 17 of Set 11 | tual
# Processing Record 18 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 19 of Set 11 | makat
# Processing Record 20 of Set 11 | dukat
# Processing Record 21 of Set 11 | mangan
# Processing Record 22 of Set 11 | boyolangu
# Processing Record 23 of Set 11 | zaliznychne
# Processing Record 24 of Set 11 | moose factory
# Processing Record 25 of Set 11 | dumaguil
# Processing Record 26 of Set 11 | garissa
# Processing Record 27 of Set 11 | nandi
# Processing Record 28 of Set 11 | launceston
# Processing Record 29 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 30 of Set 11 | lanigan
# Processing Record 31 of Set 11 | marsa matruh
# Processing Record 32 of Set 11 | vao
# Processing Record 33 of Set 11 | rosendal
# Processing Record 34 of Set 11 | dengzhou
# Processing Record 35 of Set 11 | sao desiderio
# Processing Record 36 of Set 11 | ivankiv
# Processing Record 37 of Set 11 | malacky
# Processing Record 38 of Set 11 | marienburg
# Processing Record 39 of Set 11 | egvekinot
# Processing Record 40 of Set 11 | broome
# Processing Record 41 of Set 11 | muroto
# Processing Record 42 of Set 11 | cap malheureux
# Processing Record 43 of Set 11 | caarapo
# Processing Record 44 of Set 11 | cootamundra
# Processing Record 45 of Set 11 | vila velha
# Processing Record 46 of Set 11 | kushmurun
# Processing Record 47 of Set 11 | altay
# Processing Record 48 of Set 11 | balkanabat
# Processing Record 49 of Set 11 | mozarlandia
# Processing Record 50 of Set 11 | coromandel
# Processing Record 1 of Set 12 | voh
# Processing Record 2 of Set 12 | ulaangom
# Processing Record 3 of Set 12 | bonthe
# Processing Record 4 of Set 12 | puerto del rosario
# Processing Record 5 of Set 12 | emerald
# Processing Record 6 of Set 12 | buturlinovka
# Processing Record 7 of Set 12 | khani
# Processing Record 8 of Set 12 | turayf
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | bilibino
# Processing Record 11 of Set 12 | izhmorskiy
# Processing Record 12 of Set 12 | sangmelima
# Processing Record 13 of Set 12 | bemidji
# Processing Record 14 of Set 12 | grand baie
# Processing Record 15 of Set 12 | awbari
# Processing Record 16 of Set 12 | petropavlovskoye
# Processing Record 17 of Set 12 | huilong
# Processing Record 18 of Set 12 | vytegra
# Processing Record 19 of Set 12 | oktyabrskiy
# Processing Record 20 of Set 12 | calama
# Processing Record 21 of Set 12 | narrabri
# Processing Record 22 of Set 12 | novobiryusinskiy
# Processing Record 23 of Set 12 | sterling
# Processing Record 24 of Set 12 | uniontown
# Processing Record 25 of Set 12 | sungaipenuh
# Processing Record 26 of Set 12 | banjar
# Processing Record 27 of Set 12 | bilma
# Processing Record 28 of Set 12 | puerto escondido
# Processing Record 29 of Set 12 | laibin
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | adamovka
# Processing Record 32 of Set 12 | sobolevo
# Processing Record 33 of Set 12 | svetlogorsk
# Processing Record 34 of Set 12 | ucluelet
# Processing Record 35 of Set 12 | tilichiki
# Processing Record 36 of Set 12 | kelvington
# Processing Record 37 of Set 12 | kafanchan
# Processing Record 38 of Set 12 | korla
# Processing Record 39 of Set 12 | giaveno
# Processing Record 40 of Set 12 | hervey bay
# Processing Record 41 of Set 12 | gumdag
# Processing Record 42 of Set 12 | denpasar
# Processing Record 43 of Set 12 | kattivakkam
# Processing Record 44 of Set 12 | lata
# Processing Record 45 of Set 12 | ullapool
# Processing Record 46 of Set 12 | uvinza
# Processing Record 47 of Set 12 | thinadhoo
# Processing Record 48 of Set 12 | kutum
# Processing Record 49 of Set 12 | takanosu
# Processing Record 50 of Set 12 | lahij
# Processing Record 1 of Set 13 | pitelino
# Processing Record 2 of Set 13 | nyurba
# Processing Record 3 of Set 13 | vanavara
# Processing Record 4 of Set 13 | evinayong
# Processing Record 5 of Set 13 | merauke
# Processing Record 6 of Set 13 | mvomero
# Processing Record 7 of Set 13 | stephenville
# Processing Record 8 of Set 13 | ovalle
# Processing Record 9 of Set 13 | fort-shevchenko
# Processing Record 10 of Set 13 | oranjestad
# Processing Record 11 of Set 13 | la paz
# Processing Record 12 of Set 13 | murdochville
# Processing Record 13 of Set 13 | luis correia
# Processing Record 14 of Set 13 | zhezkazgan
# Processing Record 15 of Set 13 | sfantu gheorghe
# Processing Record 16 of Set 13 | port macquarie
# Processing Record 17 of Set 13 | port pirie
# Processing Record 18 of Set 13 | tautira
# Processing Record 19 of Set 13 | mlonggo
# Processing Record 20 of Set 13 | port hawkesbury
# Processing Record 21 of Set 13 | kenai
# Processing Record 22 of Set 13 | tanout
# Processing Record 23 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 24 of Set 13 | abu samrah
# Processing Record 25 of Set 13 | chimbote
# Processing Record 26 of Set 13 | pauini
# Processing Record 27 of Set 13 | muborak
# Processing Record 28 of Set 13 | tabou
# Processing Record 29 of Set 13 | dunkwa
# Processing Record 30 of Set 13 | lagos
# Processing Record 31 of Set 13 | goure
# Processing Record 32 of Set 13 | mandalgovi
# Processing Record 33 of Set 13 | utinga
# Processing Record 34 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 13 | nakonde
# Processing Record 36 of Set 13 | vila
# Processing Record 37 of Set 13 | pareora
# Processing Record 38 of Set 13 | garowe
# Processing Record 39 of Set 13 | kirkwall
# Processing Record 40 of Set 13 | luganville
# Processing Record 41 of Set 13 | yertsevo
# Processing Record 42 of Set 13 | auly
# Processing Record 43 of Set 13 | alofi
# Processing Record 44 of Set 13 | promissao
# Processing Record 45 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 13 | lefka
# Processing Record 47 of Set 13 | turkistan
# Processing Record 48 of Set 13 | qeshm
# Processing Record 49 of Set 13 | manado
# Processing Record 50 of Set 13 | shenjiamen
# Processing Record 1 of Set 14 | severnyy
# Processing Record 2 of Set 14 | gotsu
# Processing Record 3 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 14 | khawhai
# Processing Record 5 of Set 14 | abaete
# Processing Record 6 of Set 14 | belmonte
# Processing Record 7 of Set 14 | luanda
# Processing Record 8 of Set 14 | wanderlandia
# City not found. Skipping...
# Processing Record 9 of Set 14 | orbetello
# Processing Record 10 of Set 14 | paamiut
# Processing Record 11 of Set 14 | weston
# Processing Record 12 of Set 14 | havelock
# Processing Record 13 of Set 14 | kathua
# Processing Record 14 of Set 14 | kabansk
# Processing Record 15 of Set 14 | salalah
# Processing Record 16 of Set 14 | japura
# Processing Record 17 of Set 14 | solnechnyy
# Processing Record 18 of Set 14 | isilkul
# Processing Record 19 of Set 14 | huinan
# Processing Record 20 of Set 14 | fremont
# Processing Record 21 of Set 14 | columbus
# Processing Record 22 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 14 | sambava
# Processing Record 24 of Set 14 | burica
# City not found. Skipping...
# Processing Record 25 of Set 14 | loubomo
# Processing Record 26 of Set 14 | porto novo
# Processing Record 27 of Set 14 | ibra
# Processing Record 28 of Set 14 | pudozh
# Processing Record 29 of Set 14 | santarem
# Processing Record 30 of Set 14 | santa fe
# Processing Record 31 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 32 of Set 14 | qaqortoq
# Processing Record 33 of Set 14 | bahia blanca
# Processing Record 34 of Set 14 | aripuana
# Processing Record 35 of Set 14 | valavanur
# Processing Record 36 of Set 14 | nhulunbuy
# Processing Record 37 of Set 14 | takoradi
# Processing Record 38 of Set 14 | merrill
# Processing Record 39 of Set 14 | leonidovo
# Processing Record 40 of Set 14 | kangaatsiaq
# Processing Record 41 of Set 14 | tallahassee
# Processing Record 42 of Set 14 | ahipara
# Processing Record 43 of Set 14 | great bend
# Processing Record 44 of Set 14 | teshie
# Processing Record 45 of Set 14 | camacari
# Processing Record 46 of Set 14 | filadelfia
# Processing Record 47 of Set 14 | ozernovskiy
# Processing Record 48 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 14 | conde
# Processing Record 50 of Set 14 | coronel fabriciano
# Processing Record 1 of Set 15 | waddan
# Processing Record 2 of Set 15 | majene
# Processing Record 3 of Set 15 | kaduy
# Processing Record 4 of Set 15 | olden
# Processing Record 5 of Set 15 | sorong
# Processing Record 6 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 15 | parrita
# Processing Record 8 of Set 15 | acapulco
# Processing Record 9 of Set 15 | tsabong
# Processing Record 10 of Set 15 | kampene
# Processing Record 11 of Set 15 | ormond beach
# Processing Record 12 of Set 15 | lahad datu
# Processing Record 13 of Set 15 | sapa
# Processing Record 14 of Set 15 | mishan
# Processing Record 15 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 16 of Set 15 | pitkyaranta
# Processing Record 17 of Set 15 | pemangkat
# Processing Record 18 of Set 15 | rio gallegos
# Processing Record 19 of Set 15 | san carlos de bariloche
# Processing Record 20 of Set 15 | san cristobal
# Processing Record 21 of Set 15 | mazatlan
# Processing Record 22 of Set 15 | aykhal
# Processing Record 23 of Set 15 | kununurra
# Processing Record 24 of Set 15 | sawakin
# Processing Record 25 of Set 15 | hambantota
# Processing Record 26 of Set 15 | turukhansk
# Processing Record 27 of Set 15 | umea
# Processing Record 28 of Set 15 | kautokeino
# Processing Record 29 of Set 15 | tymovskoye
# Processing Record 30 of Set 15 | karatau
# Processing Record 31 of Set 15 | brewster
# Processing Record 32 of Set 15 | opuwo
# Processing Record 33 of Set 15 | dundee
# Processing Record 34 of Set 15 | yangjiang
# Processing Record 35 of Set 15 | onda
# Processing Record 36 of Set 15 | rio branco
# Processing Record 37 of Set 15 | mawlaik
# Processing Record 38 of Set 15 | basco
# Processing Record 39 of Set 15 | port hardy
# Processing Record 40 of Set 15 | azangaro
# Processing Record 41 of Set 15 | boksitogorsk
# Processing Record 42 of Set 15 | pozoblanco
# Processing Record 43 of Set 15 | ardmore
# Processing Record 44 of Set 15 | tiznit
# Processing Record 45 of Set 15 | pasni
# Processing Record 46 of Set 15 | necochea
# Processing Record 47 of Set 15 | khimarros
# City not found. Skipping...
# Processing Record 48 of Set 15 | plettenberg bay
# Processing Record 49 of Set 15 | timra
# Processing Record 50 of Set 15 | pedernales
# Processing Record 1 of Set 16 | forestville
# Processing Record 2 of Set 16 | glendive
# Processing Record 3 of Set 16 | antofagasta
# Processing Record 4 of Set 16 | mendeleyevo
# Processing Record 5 of Set 16 | coahuayana
# Processing Record 6 of Set 16 | presidente olegario
# Processing Record 7 of Set 16 | keti bandar
# Processing Record 8 of Set 16 | landerneau
# Processing Record 9 of Set 16 | meulaboh
# Processing Record 10 of Set 16 | skibbereen
# Processing Record 11 of Set 16 | catalao
# Processing Record 12 of Set 16 | santa cruz de tenerife
# Processing Record 13 of Set 16 | meilu
# City not found. Skipping...
# Processing Record 14 of Set 16 | la ronge
# Processing Record 15 of Set 16 | lipin bor
# Processing Record 16 of Set 16 | uruzgan
# Processing Record 17 of Set 16 | christchurch
# Processing Record 18 of Set 16 | pandan
# Processing Record 19 of Set 16 | olinda
# Processing Record 20 of Set 16 | saint-georges
# Processing Record 21 of Set 16 | edgewater
# Processing Record 22 of Set 16 | longyearbyen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 715

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label="City_ID")

# %%
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dunedin      NZ -45.8742  170.5036     56.80        72         100
# 1          Oistins      BB  13.0667  -59.5333     82.49        78          40
# 2           Acarau      BR  -2.8856  -40.1200     77.85        83          60
# 3           Rognan      NO  67.0953   15.3878     48.88        93         100
# 4          Iquitos      PE  -3.7481  -73.2472     78.84        89          40
# 5     Saint George      US  37.1041 -113.5841     94.62        28           0
# 6           Dingle      PH  10.9995  122.6711     83.93        75          56
# 7  Haines Junction      CA  60.7522 -137.5108     54.25        46         100
# 8       Eslamshahr      IR  35.5605   51.2346     72.84        37          40
# 9          Awjilah      LY  29.1081   21.2869     79.99        45           0
#
#    Wind Speed Weather description
# 0        1.03     overcast clouds
# 1        9.22    scattered clouds
# 2       17.90       broken clouds
# 3        2.37     overcast clouds
# 4        4.61    scattered clouds
# 5        8.05           clear sky
# 6        7.74       broken clouds
# 7        5.14     overcast clouds
# 8       11.50    scattered clouds
# 9        8.79           clear sky
